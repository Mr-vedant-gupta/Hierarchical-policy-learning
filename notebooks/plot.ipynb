# %%
from tbparse import SummaryReader
log_dir = "/home/yash/option/Hierarchical-policy-learning/option-critic-pytorch/runs/OptionCriticFeatures-CartPole-v0-None-Thu Apr 11 07:49:54 2024/events.out.tfevents.1712836194.hotcake.612607.0"
reader = SummaryReader(log_dir)
df = reader.scalars

# %%
tags = df["tag"].unique()
for tag in tags:
    df[df["tag"] == tag].set_index("step", drop=True).plot(title=tag)
